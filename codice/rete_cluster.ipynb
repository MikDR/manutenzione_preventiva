# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os
import numpy as np

# %%
i = 1
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_0 (Healthy)'
lista = []
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista))

#Faccio la media con i valori assoluti delle accelerazioni
media_array_cl0 = np.mean(np.abs(np.array(lista)), axis=0)
print(media_array_cl0)
print(len(media_array_cl0))
# Out:
# 211
# [0.35045299 0.37975294 0.38198653 ... 0.38355809 0.39213671 0.35532465]
# 60000

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_1'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista))

#Faccio la media con i valori assoluti delle accelerazioni
media_array_cl1 = np.mean(np.abs(np.array(lista[212:])), axis=0)
print(media_array_cl1)
print(len(media_array_cl1))
# Out:
# 429
# [0.35001916 0.33865639 0.36351774 ... 0.377265   0.3690179  0.3962706 ]
# 60000

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_2'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista))

#Faccio la media con i valori assoluti delle accelerazioni
media_array_cl2 = np.mean(np.abs(np.array(lista[430:])), axis=0)
print(media_array_cl2)
print(len(media_array_cl2))
# Out:
# 642
# [0.40541999 0.36606231 0.38134743 ... 0.36663869 0.38186179 0.39712058]
# 60000

# %%
'''
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_3'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[2])
    df.name = f"df_{i}"
    lista.append(df["acc_Z"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(lista)'''
# Out:
# '\ncartella = r\'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_3\'\nfor filename in os.listdir(cartella):\n    # Costruisci il percorso completo del file\n    percorso_file = os.path.join(cartella, filename)\n\n    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico\n\n    df= pd.read_csv(percorso_file, usecols=[2])\n    df.name = f"df_{i}"\n    lista.append(df["acc_Z"].values)\n    # Stampa le prime righe del DataFrame appena creato\n    #print(df.name)\n    #print(df.head())\n\n    i += 1\nprint(lista)'

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_4'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(lista)

#Faccio la media con i valori assoluti delle accelerazioni
media_array_cl4 = np.mean(np.abs(np.array(lista[643:])), axis=0)
print(media_array_cl4)
print(len(media_array_cl4))

# %%
print(len(lista))
# Out:
# 868

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_6'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista))
#Faccio la media con i valori assoluti delle accelerazioni
media_array_cl5 = np.mean(np.abs(np.array(lista[869:])), axis=0) #Array che si riferisce alla classe 6
print(media_array_cl5)
print(len(media_array_cl5))
# Out:
# 1071
# [0.33950284 0.33153812 0.375703   ... 0.32146079 0.31575978 0.33081345]
# 60000

# %%
'''cartella = r'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_8'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[2])
    df.name = f"df_{i}"
    lista.append(df["acc_Z"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(lista)'''
# Out:
# 'cartella = r\'/content/drive/MyDrive/Progetto_manutenzione/file_cut_training/Pitting_degradation_level_8\'\nfor filename in os.listdir(cartella):\n    # Costruisci il percorso completo del file\n    percorso_file = os.path.join(cartella, filename)\n\n    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico\n\n    df= pd.read_csv(percorso_file, usecols=[2])\n    df.name = f"df_{i}"\n    lista.append(df["acc_Z"].values)\n    # Stampa le prime righe del DataFrame appena creato\n    #print(df.name)\n    #print(df.head())\n\n    i += 1\nprint(lista)'

# %%
len(lista)
# Out:
# 1071

# %%
lista_etichette_train = []

# Aggiungi i primi 211 numeri pari a 0
lista_etichette_train.extend([0] * 211)

# Aggiungi i successivi 218 numeri pari a 1
lista_etichette_train.extend([1] * 218)

# Aggiungi i successivi 213 numeri pari a 2
lista_etichette_train.extend([2] * 213)

# Aggiungi i successivi 191 numeri pari a 3
#lista_etichette_train.extend([3] * 191)

# Aggiungi i successivi 226 numeri pari a 4 // 3 equivale a classe 4
lista_etichette_train.extend([3] * 226)

# Aggiungi i successivi 203 numeri pari a 6 // 4 equivale a 6
lista_etichette_train.extend([4] * 203)

# Aggiungi i successivi 220 numeri pari a 8 //6 equivale a 8
#lista_etichette_train.extend([6] * 220)
# Stampa la lista di numeri
print(len(lista_etichette_train))
# Out:
# 1071

# %%
lista_etichette_test = []

# Aggiungi i primi 77 numeri pari a 0
lista_etichette_test.extend([0] * 77)

# Aggiungi i successivi 78 numeri pari a 1
lista_etichette_test.extend([1] * 78)

# Aggiungi i successivi 78 numeri pari a 2
lista_etichette_test.extend([2] * 78)

# Aggiungi i successivi 78 numeri pari a 3
#lista_etichette_test.extend([3] * 78)

# Aggiungi i successivi 78 numeri pari a 4
lista_etichette_test.extend([3] * 78)

# Aggiungi i successivi 78 numeri pari a 6 // 5 equivale a 6
lista_etichette_test.extend([4] * 78)

'''
  Stesso discorso del train per le etichette
'''

# Aggiungi i successivi 78 numeri pari a 8 //6 equivale a 8
#lista_etichette_test.extend([6] * 78)
# Stampa la lista di numeri
print(len(lista_etichette_test))
# Out:
# 389

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, SeparableConv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Add
import tensorflow as tf

# Input Layer
input_layer = Input(shape=(60000, 1))

# Separable_Conv1D_1
conv1 =  SeparableConv1D(32, kernel_size=3, strides=1, padding='same', activation='relu')(input_layer)
conv1_mp = MaxPooling1D(pool_size=2, padding='same')(conv1)

# Separable_Conv1D_2
conv2 =  SeparableConv1D(64, kernel_size=3, strides=1, padding='same', activation='relu')(conv1_mp)
conv2_mp = MaxPooling1D(pool_size=2, padding='same')(conv2)

# Separable_Conv1D_3
conv3 =  SeparableConv1D(64, kernel_size=3, strides=4, padding='same', activation='relu')(input_layer)

# Residual Layer 1
residual1 = Add()([conv2_mp, conv3])


# Residual Layer 2
sep_conv_4 = SeparableConv1D(128, kernel_size=3, activation='relu', padding='same')(residual1)
sep_conv_5 = SeparableConv1D(128, kernel_size=3, activation='relu', padding='same')(sep_conv_4)
sep_conv6 = SeparableConv1D(128, kernel_size=3, strides=4, activation='relu', padding='same')(input_layer)
residual2= Add()([sep_conv_5, sep_conv6])


# Global Max Pooling
global_max_pooling = GlobalMaxPooling1D()(residual2)

# Dense Layer
dense_layer = Dense(100, activation='relu')(global_max_pooling)

# Softmax Layer
softmax_layer = Dense(5, activation='softmax')(dense_layer)

# Creazione del modello
model = Model(inputs=input_layer, outputs=softmax_layer)


optimizer = tf.keras.optimizers.experimental.RMSprop(
    learning_rate=0.002,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-07
)
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=[tf.keras.metrics.CategoricalAccuracy()]
)

# Visualizzazione della struttura della rete
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60000, 1)]           0         []
#
#  separable_conv1d (Separabl  (None, 60000, 32)            67        ['input_1[0][0]']
#  eConv1D)
#
#  max_pooling1d (MaxPooling1  (None, 30000, 32)            0         ['separable_conv1d[0][0]']
#  D)
#
#  separable_conv1d_1 (Separa  (None, 30000, 64)            2208      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 15000, 64)            0         ['separable_conv1d_1[0][0]']
#  g1D)
#
#  separable_conv1d_2 (Separa  (None, 15000, 64)            131       ['input_1[0][0]']
#  bleConv1D)
#
#  add (Add)                   (None, 15000, 64)            0         ['max_pooling1d_1[0][0]',
#                                                                      'separable_conv1d_2[0][0]']
#
#  separable_conv1d_3 (Separa  (None, 15000, 128)           8512      ['add[0][0]']
#  bleConv1D)
#
#  separable_conv1d_4 (Separa  (None, 15000, 128)           16896     ['separable_conv1d_3[0][0]']
#  bleConv1D)
#
#  separable_conv1d_5 (Separa  (None, 15000, 128)           259       ['input_1[0][0]']
#  bleConv1D)
#
#  add_1 (Add)                 (None, 15000, 128)           0         ['separable_conv1d_4[0][0]',
#                                                                      'separable_conv1d_5[0][0]']
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['add_1[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 100)                  12900     ['global_max_pooling1d[0][0]']
#
#  dense_1 (Dense)             (None, 5)                    505       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 41478 (162.02 KB)
# Trainable params: 41478 (162.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
x_train = np.asarray(lista)
y_train = tf.keras.utils.to_categorical(lista_etichette_train, num_classes=5)
y_test=tf.keras.utils.to_categorical(lista_etichette_test, num_classes=5)

# %%
print(len(x_train))
# Out:
# 1071

# %%
model.fit(x_train,y_train, epochs=100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 17s 236ms/step - loss: 1.6313 - categorical_accuracy: 0.2120
# Epoch 2/100
# 34/34 [==============================] - 7s 198ms/step - loss: 1.6130 - categorical_accuracy: 0.2474
# Epoch 3/100
# 34/34 [==============================] - 7s 201ms/step - loss: 1.6066 - categorical_accuracy: 0.2596
# Epoch 4/100
# 34/34 [==============================] - 7s 201ms/step - loss: 1.5873 - categorical_accuracy: 0.3007
# Epoch 5/100
# 34/34 [==============================] - 7s 202ms/step - loss: 1.5369 - categorical_accuracy: 0.3623
# Epoch 6/100
# 34/34 [==============================] - 7s 200ms/step - loss: 1.4808 - categorical_accuracy: 0.3847
# Epoch 7/100
# 34/34 [==============================] - 7s 203ms/step - loss: 1.4167 - categorical_accuracy: 0.3968
# Epoch 8/100
# 34/34 [==============================] - 7s 203ms/step - loss: 1.3544 - categorical_accuracy: 0.4444
# Epoch 9/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.2667 - categorical_accuracy: 0.4500
# Epoch 10/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.2104 - categorical_accuracy: 0.4893
# Epoch 11/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.1802 - categorical_accuracy: 0.5042
# Epoch 12/100
# 34/34 [==============================] - 7s 209ms/step - loss: 1.1291 - categorical_accuracy: 0.5313
# Epoch 13/100
# 34/34 [==============================] - 7s 206ms/step - loss: 1.0929 - categorical_accuracy: 0.5537
# Epoch 14/100
# 34/34 [==============================] - 7s 207ms/step - loss: 1.0789 - categorical_accuracy: 0.5369
# Epoch 15/100
# 34/34 [==============================] - 7s 204ms/step - loss: 1.0561 - categorical_accuracy: 0.5490
# Epoch 16/100
# 34/34 [==============================] - 7s 204ms/step - loss: 1.0211 - categorical_accuracy: 0.5724
# Epoch 17/100
# 34/34 [==============================] - 7s 204ms/step - loss: 1.0041 - categorical_accuracy: 0.5770
# Epoch 18/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.9910 - categorical_accuracy: 0.5901
# Epoch 19/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.9681 - categorical_accuracy: 0.5929
# Epoch 20/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.9376 - categorical_accuracy: 0.5985
# Epoch 21/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.9432 - categorical_accuracy: 0.5976
# Epoch 22/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.8911 - categorical_accuracy: 0.6331
# Epoch 23/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.8962 - categorical_accuracy: 0.6256
# Epoch 24/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.8729 - categorical_accuracy: 0.6246
# Epoch 25/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.8763 - categorical_accuracy: 0.6321
# Epoch 26/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.8538 - categorical_accuracy: 0.6293
# Epoch 27/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.8399 - categorical_accuracy: 0.6452
# Epoch 28/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.8219 - categorical_accuracy: 0.6508
# Epoch 29/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.8085 - categorical_accuracy: 0.6489
# Epoch 30/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7952 - categorical_accuracy: 0.6657
# Epoch 31/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.7831 - categorical_accuracy: 0.6685
# Epoch 32/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7724 - categorical_accuracy: 0.6797
# Epoch 33/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.7310 - categorical_accuracy: 0.7031
# Epoch 34/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.7319 - categorical_accuracy: 0.6816
# Epoch 35/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.7089 - categorical_accuracy: 0.7087
# Epoch 36/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6912 - categorical_accuracy: 0.7049
# Epoch 37/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6927 - categorical_accuracy: 0.7077
# Epoch 38/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6538 - categorical_accuracy: 0.7227
# Epoch 39/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6551 - categorical_accuracy: 0.7414
# Epoch 40/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6485 - categorical_accuracy: 0.7358
# Epoch 41/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.6185 - categorical_accuracy: 0.7460
# Epoch 42/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.6206 - categorical_accuracy: 0.7423
# Epoch 43/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.5896 - categorical_accuracy: 0.7432
# Epoch 44/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.5649 - categorical_accuracy: 0.7638
# Epoch 45/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.5621 - categorical_accuracy: 0.7563
# Epoch 46/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.5573 - categorical_accuracy: 0.7862
# Epoch 47/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.5365 - categorical_accuracy: 0.7852
# Epoch 48/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.5467 - categorical_accuracy: 0.7815
# Epoch 49/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.5177 - categorical_accuracy: 0.7890
# Epoch 50/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.4831 - categorical_accuracy: 0.7965
# Epoch 51/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.4882 - categorical_accuracy: 0.7824
# Epoch 52/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.4489 - categorical_accuracy: 0.8161
# Epoch 53/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.4704 - categorical_accuracy: 0.8263
# Epoch 54/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.4569 - categorical_accuracy: 0.8170
# Epoch 55/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.4447 - categorical_accuracy: 0.8179
# Epoch 56/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.4241 - categorical_accuracy: 0.8329
# Epoch 57/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.4397 - categorical_accuracy: 0.8226
# Epoch 58/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.4223 - categorical_accuracy: 0.8413
# Epoch 59/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.3999 - categorical_accuracy: 0.8385
# Epoch 60/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.3746 - categorical_accuracy: 0.8515
# Epoch 61/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.3794 - categorical_accuracy: 0.8422
# Epoch 62/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.3595 - categorical_accuracy: 0.8627
# Epoch 63/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.3783 - categorical_accuracy: 0.8487
# Epoch 64/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.3172 - categorical_accuracy: 0.8693
# Epoch 65/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.3784 - categorical_accuracy: 0.8721
# Epoch 66/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.3810 - categorical_accuracy: 0.8646
# Epoch 67/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.3180 - categorical_accuracy: 0.8917
# Epoch 68/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.3516 - categorical_accuracy: 0.8683
# Epoch 69/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.3036 - categorical_accuracy: 0.8964
# Epoch 70/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.3014 - categorical_accuracy: 0.8814
# Epoch 71/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.2919 - categorical_accuracy: 0.8824
# Epoch 72/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.3304 - categorical_accuracy: 0.8739
# Epoch 73/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.2844 - categorical_accuracy: 0.9113
# Epoch 74/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.3079 - categorical_accuracy: 0.8702
# Epoch 75/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.3145 - categorical_accuracy: 0.9020
# Epoch 76/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2181 - categorical_accuracy: 0.9234
# Epoch 77/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2375 - categorical_accuracy: 0.9169
# Epoch 78/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.2933 - categorical_accuracy: 0.8973
# Epoch 79/100
# 34/34 [==============================] - 7s 208ms/step - loss: 0.2395 - categorical_accuracy: 0.9141
# Epoch 80/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2531 - categorical_accuracy: 0.9188
# Epoch 81/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.2394 - categorical_accuracy: 0.9225
# Epoch 82/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.1956 - categorical_accuracy: 0.9197
# Epoch 83/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2885 - categorical_accuracy: 0.9104
# Epoch 84/100
# 34/34 [==============================] - 7s 208ms/step - loss: 0.2268 - categorical_accuracy: 0.9365
# Epoch 85/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.1977 - categorical_accuracy: 0.9384
# Epoch 86/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2282 - categorical_accuracy: 0.9328
# Epoch 87/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2533 - categorical_accuracy: 0.9197
# Epoch 88/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1756 - categorical_accuracy: 0.9430
# Epoch 89/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.2061 - categorical_accuracy: 0.9449
# Epoch 90/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1785 - categorical_accuracy: 0.9412
# Epoch 91/100
# 34/34 [==============================] - 7s 204ms/step - loss: 0.2027 - categorical_accuracy: 0.9356
# Epoch 92/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1602 - categorical_accuracy: 0.9412
# Epoch 93/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.2020 - categorical_accuracy: 0.9393
# Epoch 94/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1491 - categorical_accuracy: 0.9524
# Epoch 95/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1626 - categorical_accuracy: 0.9580
# Epoch 96/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.1555 - categorical_accuracy: 0.9570
# Epoch 97/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1726 - categorical_accuracy: 0.9533
# Epoch 98/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.1427 - categorical_accuracy: 0.9561
# Epoch 99/100
# 34/34 [==============================] - 7s 208ms/step - loss: 0.2066 - categorical_accuracy: 0.9514
# Epoch 100/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.1605 - categorical_accuracy: 0.9505

# %%
i = 1
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_0 (Healthy)'
lista_test = []
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_test.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista_test))
# Out:
# 77

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_1'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_test.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista_test))
# Out:
# 155

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_2'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_test.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista_test))
# Out:
# 233

# %%
'''cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_3'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[2])
    df.name = f"df_{i}"
    lista_test.append(df["acc_Z"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(lista_test)'''
# Out:
# 'cartella = r\'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_3\'\nfor filename in os.listdir(cartella):\n    # Costruisci il percorso completo del file\n    percorso_file = os.path.join(cartella, filename)\n\n    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico\n\n    df= pd.read_csv(percorso_file, usecols=[2])\n    df.name = f"df_{i}"\n    lista_test.append(df["acc_Z"].values)\n    # Stampa le prime righe del DataFrame appena creato\n    #print(df.name)\n    #print(df.head())\n\n    i += 1\nprint(lista_test)'

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_4'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_test.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista_test))
# Out:
# 311

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_6'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_test.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(len(lista_test))
# Out:
# 389

# %%
'''cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_8'
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[2])
    df.name = f"df_{i}"
    lista_test.append(df["acc_Z"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
print(lista_test)'''
# Out:
# 'cartella = r\'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_8\'\nfor filename in os.listdir(cartella):\n    # Costruisci il percorso completo del file\n    percorso_file = os.path.join(cartella, filename)\n\n    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico\n\n    df= pd.read_csv(percorso_file, usecols=[2])\n    df.name = f"df_{i}"\n    lista_test.append(df["acc_Z"].values)\n    # Stampa le prime righe del DataFrame appena creato\n    #print(df.name)\n    #print(df.head())\n\n    i += 1\nprint(lista_test)'

# %%
x_test = np.asarray(lista_test)
print(len(y_test))
# Out:
# 389

# %%
evaluation = model.evaluate(x_test, y_test)
print(evaluation)
# Out:
# 13/13 [==============================] - 2s 110ms/step - loss: 0.7956 - categorical_accuracy: 0.7712
# [0.7956477999687195, 0.7712082266807556]

# %%
prediction = model.predict(x_test)
# Out:
# 13/13 [==============================] - 1s 85ms/step

# %%
# Trova l'indice della classe con la probabilità più alta per ciascun vettore di probabilità
indici_classi_predette = np.argmax(prediction, axis=1)
# Crea la matrice one-hot
matrice_one_hot = np.eye(prediction.shape[1])[indici_classi_predette]

from sklearn.metrics import precision_score, recall_score
print(precision_score(y_test,matrice_one_hot, average='macro'))
print(recall_score(y_test,matrice_one_hot, average='macro'))
# Out:
# 0.7784388025767335
# 0.7705960705960706

# %%
from sklearn.metrics import confusion_matrix
# Converte la matrice one-hot in etichette predette
etichette_predette = np.argmax(matrice_one_hot, axis=1)

# Converte y_test in etichette reali
etichette_reali = np.argmax(y_test, axis=1)

# Calcola la matrice di confusione
matrice_confusione = confusion_matrix(etichette_reali, etichette_predette)

#confusion_matrix(y_test, matrice_one_hot)

# %%
print("Matrice di confusione:")
print(matrice_confusione)
# Out:
# Matrice di confusione:
# [[41 14  7  0 15]
#  [ 6 64  4  2  2]
#  [ 1  1 67  1  8]
#  [ 1  5  2 66  4]
#  [ 3  3  7  3 62]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot della matrice di confusione utilizzando seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(matrice_confusione, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Classe Predetta')
plt.ylabel('Classe Reale')
plt.title('Matrice di Confusione')
plt.show()

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_3'
lista_classe_3 = []
i=0
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_classe_3.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1
x_test_classe_3 = np.asarray(lista_classe_3)

# %%
cartella = r'/content/drive/MyDrive/Progetto_manutenzione/hold_out_test/Pitting_degradation_level_8'
lista_classe_8 = []
i=0
for filename in os.listdir(cartella):
    # Costruisci il percorso completo del file
    percorso_file = os.path.join(cartella, filename)

    # Leggi solo la terza colonna del file CSV in un DataFrame e assegna un nome dinamico

    df= pd.read_csv(percorso_file, usecols=[0])
    df.name = f"df_{i}"
    lista_classe_8.append(df["acc_X"].values)
    # Stampa le prime righe del DataFrame appena creato
    #print(df.name)
    #print(df.head())

    i += 1

x_test_classe_8 = np.asarray(lista_classe_8)

# %%
predictions_classe_3= model.predict(x_test_classe_3)
predictions_classe_8= model.predict(x_test_classe_8)

predizioni_classe_3 = np.argmax(predictions_classe_3, axis=1)
predizioni_classe_8 = np.argmax(predictions_classe_8, axis=1)

print(predizioni_classe_3)
print(predizioni_classe_8)
# Out:
# 3/3 [==============================] - 1s 407ms/step
# 3/3 [==============================] - 0s 86ms/step
# [3 3 3 4 3 3 3 1 3 3 1 1 1 3 3 0 1 3 1 1 3 0 1 0 3 3 1 1 3 3 3 3 3 3 1 3 3
#  1 1 3 4 3 3 3 3 3 3 4 3 2 1 3 3 2 1 3 3 3 3 3 1 3 3 3 3 3 3 3 1 3 3 2 3 4
#  3 3 4 3]
# [4 4 4 4 4 2 4 1 2 2 4 4 2 2 0 4 2 2 4 4 4 2 2 2 4 4 4 4 2 2 4 4 4 4 4 4 4
#  4 2 0 2 2 4 4 4 4 4 2 4 2 4 4 4 4 0 4 4 4 4 4 4 4 4 4 2 4 2 2 4 2 2 2 4 2
#  0 4 4 4]

# %%
x_test_classe_0 = x_test[0:77]
x_test_classe_1 = x_test[78:155]
x_test_classe_2 = x_test[156:233]
#x_test_classe_3
x_test_classe_4 = x_test[234:311]
x_test_classe_6 = x_test[312:388]
#x_test_classe_8

# %%
vettori_predetti_0 = []
vettori_predetti_1 = []
vettori_predetti_2 = []
vettori_predetti_3 = []
vettori_predetti_4 = []

# %%
predictions_classe_0 = model.predict(x_test_classe_0)
predictions_classe_1 = model.predict(x_test_classe_1)
predictions_classe_2 = model.predict(x_test_classe_2)
predictions_classe_3 = model.predict(x_test_classe_3)
predictions_classe_4 = model.predict(x_test_classe_4)
predictions_classe_6 = model.predict(x_test_classe_6)
predictions_classe_8 = model.predict(x_test_classe_8)
# Out:
# 3/3 [==============================] - 0s 89ms/step
# 3/3 [==============================] - 0s 82ms/step
# 3/3 [==============================] - 0s 80ms/step
# 3/3 [==============================] - 0s 87ms/step
# 3/3 [==============================] - 0s 82ms/step
# 3/3 [==============================] - 1s 357ms/step
# 3/3 [==============================] - 0s 81ms/step

# %%
predictions_cifre_classe_0 = []
predictions_cifre_classe_1 = []
predictions_cifre_classe_2 = []
predictions_cifre_classe_3 = []
predictions_cifre_classe_4 = []
predictions_cifre_classe_6 = []
predictions_cifre_classe_8 = []

# %%
for vettore in predictions_classe_0:
  predictions_cifre_classe_0.append(np.argmax(vettore))

for vettore in predictions_classe_1:
  predictions_cifre_classe_1.append(np.argmax(vettore))

for vettore in predictions_classe_2:
  predictions_cifre_classe_2.append(np.argmax(vettore))

for vettore in predictions_classe_3:
  predictions_cifre_classe_3.append(np.argmax(vettore))

for vettore in predictions_classe_4:
  predictions_cifre_classe_4.append(np.argmax(vettore))

for vettore in predictions_classe_6:
  predictions_cifre_classe_6.append(np.argmax(vettore))

for vettore in predictions_classe_8:
  predictions_cifre_classe_8.append(np.argmax(vettore))

# %%
for index, prediction in enumerate(predictions_cifre_classe_0):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_0[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_0[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_0[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_0[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_0[index])

for index, prediction in enumerate(predictions_cifre_classe_1):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_1[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_1[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_1[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_1[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_1[index])

for index, prediction in enumerate(predictions_cifre_classe_2):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_2[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_2[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_2[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_2[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_2[index])

for index, prediction in enumerate(predictions_cifre_classe_3):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_3[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_3[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_3[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_3[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_3[index])

for index, prediction in enumerate(predictions_cifre_classe_4):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_4[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_4[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_4[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_4[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_4[index])

for index, prediction in enumerate(predictions_cifre_classe_6):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_6[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_6[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_6[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_6[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_6[index])

for index, prediction in enumerate(predictions_cifre_classe_8):
  if prediction == 0:
    vettori_predetti_0.append(x_test_classe_8[index])
  if prediction == 1:
    vettori_predetti_1.append(x_test_classe_8[index])
  if prediction == 2:
    vettori_predetti_2.append(x_test_classe_8[index])
  if prediction == 3:
    vettori_predetti_3.append(x_test_classe_8[index])
  if prediction == 4:
    vettori_predetti_4.append(x_test_classe_8[index])

# %%
# andiamo ad utilizzare il metodo del k-dist per individuare il numero ottimale di epsilon

colonnes_per_dbscan = ['acc_X']
df_dbscan = df_corr[colonnes_per_dbscan]

# Standardizza le colonne per avere media zero e deviazione standard uno
scaler = StandardScaler()
df_dbscan_scaled = scaler.fit_transform(df_dbscan)

neighbors = NearestNeighbors(n_neighbors=20)
neighbors_fit = neighbors.fit(df_dbscan_scaled)
distances, indices = neighbors_fit.kneighbors(df_dbscan_scaled)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.grid(True, color = "#CCCCCC")
plt.plot(distances)
#plt.savefig("../../images/clustering/dbscan/k_dist.png")# non salviamo perche modificato a mano
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-d30fba84c80d> in <cell line: 4>()
#       2
#       3 colonnes_per_dbscan = ['yellow_cards', 'goals', 'minutes_played']
# ----> 4 df_dbscan = df_corr[colonnes_per_dbscan]
#       5
#       6 # Standardizza le colonne per avere media zero e deviazione standard uno
#
# NameError: name 'df_corr' is not defined

# %%
# !pip install scikit-learn
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
# Definisci i range per eps e min_samples
eps_values = [0.005]
min_samples_values = range(4, 10)

# Inizializza una matrice per memorizzare i risultati della silhouette score
silhouette_matrix = np.zeros((len(eps_values), len(min_samples_values)))

# Itera su eps e min_samples
for i, eps in enumerate(eps_values):
    for j, min_samples in enumerate(min_samples_values):
        # Utilizza DBSCAN per il clustering con i parametri correnti
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(vettori_predetti_3)
        # Calcola la silhouette score e memorizzala nella matrice
        silhouette_avg = silhouette_score(vettori_predetti_3, labels)
        silhouette_matrix[i, j] = silhouette_avg



# Crea un heatmap della matrice della silhouette score
plt.figure(figsize=(10, 6))
sns.heatmap(silhouette_matrix, annot=True, fmt=".3f",
            xticklabels=min_samples_values, yticklabels=np.round(eps_values, 3),
            cmap="viridis", cbar_kws={'label': 'Silhouette Score'})

#plt.savefig("../../images/silhoutte_dbscan_piccola.png")
plt.xlabel('Min Samples')
plt.ylabel('Eps')
plt.title('Heatmap della Silhouette Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-6784fcb34a98> in <cell line: 9>()
#      13         labels = dbscan.fit_predict(vettori_predetti_3)
#      14         # Calcola la silhouette score e memorizzala nella matrice
# ---> 15         silhouette_avg = silhouette_score(vettori_predetti_3, labels)
#      16         silhouette_matrix[i, j] = silhouette_avg
#      17
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     229     n_samples = len(labels)
#     230     label_freqs = np.bincount(labels)
# --> 231     check_number_of_labels(len(le.classes_), n_samples)
#     232
#     233     kwds["metric"] = metric
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_unsupervised.py in check_number_of_labels(n_labels, n_samples)
#      31     """
#      32     if not 1 < n_labels < n_samples:
# ---> 33         raise ValueError(
#      34             "Number of labels is %d. Valid values are 2 to n_samples - 1 (inclusive)"
#      35             % n_labels
#
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
